# %%
from random import randint, random, shuffle, seed
from pprint import pprint
import math
import json
import unittest

# %%
class Ledger:
    def __init__(self):
        self.balances = {}  ## dictionary where the key is the user and the value is the balance the user have
        #### and it is updated each time a valid transaction is executed

        self.stats = {"n_tx": 0,  ## Total Number of transactions
                      "n_coin_tx": 0,  ## Total Number of transactions that 'coinbase' is the sender( fr )
                      "n_valid_tx": 0,
                      ## Total Number of transactions that are valid and the sender(fr) is not 'coinbase'
                      "n_invalid_to_tx": 0,  ## Total Number of transactions that are not valid because the reciver(to)
                      ## is 'coinbase'
                      "n_invalid_neg_amnt": 0,
                      ## Total Number of transactions that are not valid because the amount of trans.
                      ## is negative
                      "n_invalid_fr_tx": 0,  ## Total Number of transactions that are not valid because
                      ## the sender(fr) does not have balance
                      "n_invalid_nofund_tx": 0  ## ## Total Number of transactions that are not valid because
                      ## the amount of trans. is bigger than the balance of the sender(fr)
                      }

    def validate_transaction(self, fr, to, amount):
        # True Cases
        if fr == 'coinbase' and amount >= 0:
            self.stats['n_tx'] += 1
            self.stats['n_coin_tx'] += 1
            return True
        elif (fr in self.balances ) and (amount <= self.balances[fr]) and  ( amount >= 0) and  not ( to =='coinbase'):
            self.stats['n_tx'] += 1
            self.stats['n_valid_tx'] += 1
            return True
            # True_checker = None
            # TrueSender_checker = None
            # balance_checker = None
            # for key,value  in self.balances.items() :
            # if fr == key and amount < value:
            #    True_checker = True  # has an account
            # if key == to :
            # TrueSender_checker =True
            # if key == fr:
            # balance_checker = value

        # False Cases
        # (if not Elif because you don't stated that it couldn't be more than one False Case in the False transaction)
        if to == 'coinbase':
            self.stats['n_tx'] += 1
            self.stats['n_invalid_to_tx'] += 1
            #return False
        elif fr not in self.balances:
            self.stats['n_tx'] += 1
            self.stats['n_invalid_fr_tx'] += 1
            return False

        if amount < 0:
            self.stats['n_tx'] += 1
            self.stats['n_invalid_neg_amnt'] += 1
            #return False
        if amount > self.balances[fr]:
            self.stats['n_tx'] += 1
            self.stats['n_invalid_nofund_tx'] += 1
            #return False
        return False



            #### Add your code below
            #### check fr, to, amount variabile and return true if the transaction is valid , False otherwise
            #### in addition you should update the stats dictionary:
            ####  you should n_tx increment by 1 each time you call validate transaction and increment by 1
            ####  ( n_coin_tx ,n_valid_tx ,n_invalid_to_tx ,n_invalid_neg_amnt ,n_invalid_fr_tx ,n_invalid_nofund_tx )

    def execute_transaction(self, tx):

        if self.validate_transaction(tx['fr'], tx['to'], tx['amount']) == True:
            print tx
            if tx['fr'] == 'coinbase' and tx['amount'] >= 0:
                if tx['to'] not in self.balances:
                    self.balances[tx['to']] = 0
                print 'TX NEWCOIN OK:', tx['fr']
                print tx['to'], self.balances[tx['to']]
                # update self.balances
                self.balances[tx['to']] += tx['amount']
                print tx['amount'], "-->", tx['to']
                print (tx['to'], self.balances[tx['to']])
            elif tx['fr'] in self.balances and tx['amount'] <= self.balances[tx['fr']]:
                if tx['to'] not in self.balances:
                    self.balances[tx['to']] = 0
                print 'TX OK'
                print '--before--'
                print (tx['fr'], self.balances[tx['fr']])
                print (tx['to'], self.balances[tx['fr']])
                print '----------'
                # update self.balances
                self.balances[tx['fr']] -= tx['amount']
                self.balances[tx['to']] += tx['amount']
                print  tx['fr'], '-- ', tx['amount'], '-->', tx['to']
                print '--after--'
                print (tx['fr'], self.balances[tx['fr']])
                print (tx['fr'], self.balances[tx['to']])

        #elif self.validate_transaction(tx['fr'], tx['to'], tx['amount']) == False:
        else :
            print tx
            # print 'tx is invalid'
            if tx['to'] == 'coinbase':
                print 'reciver(to) is equal to coinbase '
            elif tx['amount'] < 0:
                print 'TX NEGATIVE AMOUNT', tx['amount']
            elif tx['fr'] not in self.balances:
                print "sender(fr) does not have an account (NOT in the balance dictionary) "

            elif tx['amount'] > self.balances[tx['fr']]:

                print 'the balance of', tx['fr'], 'is equal to', self.balances[tx['fr']]
                print 'TX NO FUNDS', self.balances[tx['fr']] - tx['amount']

        print "==================================================="

        #### Add your code below
        #### use validate_transaction funtion to check if tx(transaction) is validate o not
        #### and update the stats and balance of users  if the tx is valid

# %% [markdown]
# Expected output from
# ```python
# validate_transaction(fr, to, amount)
# ```
#  True when
#    1. sender(fr) == 'coinbase' && and amount is positive
#    2. sender(fr) is a key in balance dictionary (sender(fr) has an account ) && and amount is smaller than the balance of the sender(fr)
#
# False when
#   1. reciver(to) is equal to 'coinbase'
#   2. amount is negative
#   3. sender(fr) does not have an account (NOT in the balance dictionary)
#   4. amount is bigger than the balance of the sender(fr)
#
# Expected output of
# ```python
# validate_transaction( 'coinbase' , 'Eula Zahar', 100 )
# ```
# is True
#
# and the stats['n_coin_tx'] && stats['n_tx'] will be  increment by 1
#
# Expected output of
# ```python
# validate_transaction(  'Eula Zahar','coinbase' , 100 )
# ```
#
# is False because to is equal to coinbase
# and the stats['n_invalid_to_tx'] && stats['n_tx'] will be  increment by 1
#
# Expected output of
# ```python
# validate_transaction( 'coinbase' , 'Eula Zahar', -100 )
# ```
# is False because amount is negative
# and the stats['n_invalid_neg_amnt'] && stats['n_tx'] will be  increment by 1
#
#  =================================
#
# Expected output from execute_transaction(tx) is
#     1. if the tx is valid, the balance dictionary will be updated and you will print the balance of the user before the transaction and after and the transaction
#     Example for transaction
# ```python
# execute_transaction ( {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'} )
# ```
#     ==>
#         TX NEWCOIN OK: coinbase
#         ('Eula Zahar', 0)
#         '100  --> Eula Zahar'
#         ('Eula Zahar', 100)
#
#     2. if the tx is invalid, you will print the transaction and the why it is not valid
#         Example for transaction
# ```python
#     execute_transaction ( {'amount': 192, 'fr': 'Alma Hindman', 'to': 'Sophie Hardin'} )
#  ```
#         and the balance of Alma Hindman is equal to 100
#             TX NO FUNDS 100 - 111
#
#         Example for transaction execute_transaction ('Eula Zahar', 'Leslie Collingsworth', -11)
#             TX NEGATIVE AMOUNT -11

# %%
class TestingLedger(unittest.TestCase):
    def setUp(self):
        self.ledger = Ledger()
        self.txs = json.load(open('transactions.json'))
        #print (self.txs[10])
        #print 'Hi', self.txs[14]

    def test_validate_transaction_valid_TX_NEWCOIN_OK(self):#1
        print 'Number 1'
        self.assertEqual(self.ledger.validate_transaction('coinbase', 'Eula Zahar', 100), True)
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)

    def test_validate_transaction_invalid_TX_BAD_FR(self):#2
        print 'Number 2'
        self.assertEqual(self.ledger.validate_transaction('Carol Clark', 'Eula Zahar', 100), False)
        self.assertEqual(self.ledger.stats['n_invalid_fr_tx'], 1)

    def test_validate_transaction_invalid_TX_BAD_FR_2(self):#3
        print 'Number 3'
        self.assertEqual(self.ledger.validate_transaction('Eula Zahar', 'Carol Clark', 100), False)
        self.assertEqual(self.ledger.stats['n_invalid_fr_tx'], 1)

    def test_validate_transaction_invalid_NO_FUNDS(self):#4
        print 'Number 4'
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.validate_transaction('Eula Zahar', 'Leslie Collingsworth', 111), False)
        #print self.ledger.stats
        self.assertEqual(self.ledger.stats['n_invalid_nofund_tx'], 1)


    def test_validate_transaction_valid(self):#5
        print 'Number 5'
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.validate_transaction('Eula Zahar', 'Leslie Collingsworth', 11), True)
        self.assertEqual(self.ledger.stats['n_valid_tx'], 1)
        self.assertEqual(self.ledger.stats['n_tx'], 2) # changed to 2

    def test_validate_transaction_valid_TX_NEWCOIN_OK_2(self):#6
        print 'Number 6'
        self.assertEqual(self.ledger.validate_transaction('coinbase', 'Eula Zahar', 0), True)
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)

    def test_validate_transaction_invalid_TX_NEGATIVE_AMOUNT(self):#7
        print 'Number 7'
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.validate_transaction('Eula Zahar', 'Leslie Collingsworth', -11), False)
        self.assertEqual(self.ledger.stats['n_invalid_neg_amnt'], 1)

    def test_validate_transaction_invalid_TX_BAD_TO(self):#8
        print 'Number 8'
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.validate_transaction('Eula Zahar', 'coinbase', 11), False)
        self.assertEqual(self.ledger.stats['n_invalid_to_tx'], 1)

    def test_execute_transaction_valid(self):#9
        print 'Number 9'
        self.assertEqual(self.ledger.balances, {})
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.balances['Eula Zahar'], 100)
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)

    def test_execute_transaction_invalid_TX_BAD_FR(self):#
        print 'Number 10'
        self.assertEqual(self.ledger.balances, {})
        self.ledger.execute_transaction(self.txs[14])
        print 'Hi1', self.ledger.stats
        self.assertEqual( 'Donald Martin' in self.ledger.balances, False)
        #print 'Hi2' ,self.ledger.stats
        self.assertEqual(self.ledger.stats['n_invalid_fr_tx'], 1)######

    def test_execute_transaction_invalid_NO_FUNDS(self):
        self.assertEqual(self.ledger.balances, {})
        self.ledger.execute_transaction(self.txs[0])
        self.ledger.execute_transaction(self.txs[10])
        self.assertEqual(self.ledger.balances['Eula Zahar'], 100)
        self.assertEqual(self.ledger.stats['n_invalid_nofund_tx'], 1)
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)

    def test_execute_transaction_invalid_TX_NEGATIVE_AMOUNT(self):
        self.assertEqual(self.ledger.balances, {})
        self.ledger.execute_transaction(self.txs[0])
        self.assertEqual(self.ledger.balances['Eula Zahar'], 100)
        self.ledger.execute_transaction({'amount': -11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'} )
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)
        self.assertEqual(self.ledger.stats['n_invalid_neg_amnt'], 1)
        self.assertEqual(self.ledger.balances['Eula Zahar'], 100)

    def test_execute_transaction_valid_TX_OK(self):
        self.assertEqual(self.ledger.balances, {})
        self.ledger.execute_transaction(self.txs[0])
        self.ledger.execute_transaction({'amount': 11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'} )
        self.assertEqual(self.ledger.stats['n_coin_tx'], 1)
        self.assertEqual(self.ledger.stats['n_valid_tx'], 1)
        self.assertEqual(self.ledger.balances['Eula Zahar'], 89)
        self.assertEqual(self.ledger.balances['Leslie Collingsworth'], 11)

    def test_all_execute_transaction(self):

        self.assertEqual(self.ledger.balances, {})
        for tx in self.txs:
            self.ledger. execute_transaction(tx)
        self.assertEqual(self.ledger.stats['n_coin_tx'], 11)
        self.assertEqual(self.ledger.stats['n_invalid_fr_tx'], 2)
        self.assertEqual(self.ledger.stats['n_invalid_nofund_tx'], 4)
        self.assertEqual(self.ledger.stats['n_tx'], 21)
        self.assertEqual(self.ledger.stats['n_valid_tx'], 4)
        self.assertEqual(self.ledger.balances['Eula Zahar'], 34)
        self.assertEqual(self.ledger.balances['Carol Devoe'], 100)
        self.assertEqual(self.ledger.balances['Margaret Williams'], 100)
        self.assertEqual(self.ledger.balances['Sophie Hardin'], 100)
        self.assertEqual(self.ledger.balances['Alma Hindman'], 166)
        self.assertEqual(self.ledger.balances['Karen Langford'], 298)
        self.assertEqual(self.ledger.balances['Leslie Collingsworth'], 100)
        self.assertEqual(self.ledger.balances['Shannon Cano'], 2)
        self.assertEqual(self.ledger.balances['Steven Scott'], 100)
        self.assertEqual(self.ledger.balances['Donald Martin'], 100)

suite = unittest.TestLoader().loadTestsFromTestCase(TestingLedger)
unittest.TextTestRunner().run(suite)
# Out:
# ..............
# {u'to': u'Eula Zahar', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Eula Zahar 0
# 100 --> Eula Zahar
# (u'Eula Zahar', 100)
# ...
# {u'to': u'Carol Devoe', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Carol Devoe 0
# 100 --> Carol Devoe
# (u'Carol Devoe', 100)
# ...
# {u'to': u'Margaret Williams', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Margaret Williams 0
# 100 --> Margaret Williams
# (u'Margaret Williams', 100)
# ...
# {u'to': u'Sophie Hardin', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Sophie Hardin 0
# 100 --> Sophie Hardin
# (u'Sophie Hardin', 100)
# ...
# {u'to': u'Alma Hindman', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Alma Hindman 0
# 100 --> Alma Hindman
# (u'Alma Hindman', 100)
# ...
# {u'to': u'Karen Langford', u'fr': u'coinbase', u'amount': 100}
# TX NEWCOIN OK: coinbase
# Karen Langford 0
# 100 --> Karen Langford
# (u'Karen Langford', 100)
# ...

# %% [markdown]
# the expected output when you run the all transactions in transactions.json file
#
# Ledger.balances ==>  {
#
#                      'Alma Hindman': 166,
#                      'Carol Devoe': 100,
#                      'Donald Martin': 100,
#                      'Eula Zahar': 34,
#                      'Karen Langford': 298,
#                      'Leslie Collingsworth': 100,
#                      'Margaret Williams': 100,
#                      'Shannon Cano': 2,
#                      'Sophie Hardin': 100,
#                      'Steven Scott': 100
#
#                    }
#
# Ledger.stats ==> {
#
#                     'n_coin_tx': 11,
#                     'n_invalid_fr_tx': 2,
#                     'n_invalid_neg_amnt': 0,
#                     'n_invalid_nofund_tx': 4,
#                     'n_invalid_to_tx': 0,
#                     'n_tx': 21,
#                     'n_valid_tx': 4
#                  }
#
#
# Output printed after runing transaction
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Carol Devoe'}
#     TX NEWCOIN OK: coinbase
#     ('Carol Devoe', 0)
#     '100  --> Carol Devoe'
#     ('Carol Devoe', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Margaret Williams'}
#     TX NEWCOIN OK: coinbase
#     ('Margaret Williams', 0)
#     '100  --> Margaret Williams'
#     ('Margaret Williams', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Sophie Hardin'}
#     TX NEWCOIN OK: coinbase
#     ('Sophie Hardin', 0)
#     '100  --> Sophie Hardin'
#     ('Sophie Hardin', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Alma Hindman'}
#     TX NEWCOIN OK: coinbase
#     ('Alma Hindman', 0)
#     '100  --> Alma Hindman'
#     ('Alma Hindman', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Karen Langford'}
#     TX NEWCOIN OK: coinbase
#     ('Karen Langford', 0)
#     '100  --> Karen Langford'
#     ('Karen Langford', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Leslie Collingsworth'}
#     TX NEWCOIN OK: coinbase
#     ('Leslie Collingsworth', 0)
#     '100  --> Leslie Collingsworth'
#     ('Leslie Collingsworth', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Shannon Cano'}
#     TX NEWCOIN OK: coinbase
#     ('Shannon Cano', 0)
#     '100  --> Shannon Cano'
#     ('Shannon Cano', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Steven Scott'}
#     TX NEWCOIN OK: coinbase
#     ('Steven Scott', 0)
#     '100  --> Steven Scott'
#     ('Steven Scott', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Donald Martin'}
#     TX NEWCOIN OK: coinbase
#     ('Donald Martin', 0)
#     '100  --> Donald Martin'
#     ('Donald Martin', 100)
#
#     ===========================
#     {'amount': 111, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
#     TX NO FUNDS 100 - 111
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Shannon Cano'}
#     TX NEWCOIN OK: coinbase
#     ('Shannon Cano', 100)
#     '100  --> Shannon Cano'
#     ('Shannon Cano', 200)
#
#     ===========================
#     {'amount': 83, 'fr': 'Steven Scott', 'to': 'Steven Scott'}
#     'TX OK'
#     '--before--'
#     ('Steven Scott', 100)
#     ('Steven Scott', 100)
#     '----------'
#     'Steven Scott -- 83  --> Steven Scott'
#     '--after--'
#     ('Steven Scott', 100)
#     ('Steven Scott', 100)
#
#     ===========================
#     {'amount': 192, 'fr': 'Alma Hindman', 'to': 'Sophie Hardin'}
#     TX NO FUNDS 100 - 192
#
#     ===========================
#     {'amount': 198, 'fr': 'Carol Clark', 'to': 'Donald Martin'}
#     TX BAD FR: Carol Clark
#
#     ===========================
#     {'amount': 54, 'fr': 'Alice Miller', 'to': 'Karen Langford'}
#     TX BAD FR: Alice Miller
#
#     ===========================
#     {'amount': 104, 'fr': 'Carol Devoe', 'to': 'Steven Scott'}
#     TX NO FUNDS 100 - 104
#
#     ===========================
#     {'amount': 66, 'fr': 'Eula Zahar', 'to': 'Alma Hindman'}
#     'TX OK'
#     '--before--'
#     ('Eula Zahar', 100)
#     ('Alma Hindman', 100)
#     '----------'
#     'Eula Zahar -- 66  --> Alma Hindman'
#     '--after--'
#     ('Eula Zahar', 34)
#     ('Alma Hindman', 166)
#
#     ===========================
#     {'amount': 142, 'fr': 'Sophie Hardin', 'to': 'Steven Scott'}
#     TX NO FUNDS 100 - 142
#
#     ===========================
#     {'amount': 198, 'fr': 'Shannon Cano', 'to': 'Karen Langford'}
#     'TX OK'
#     '--before--'
#     ('Shannon Cano', 200)
#     ('Karen Langford', 100)
#     '----------'
#     'Shannon Cano -- 198  --> Karen Langford'
#     '--after--'
#     ('Shannon Cano', 2)
#     ('Karen Langford', 298)
#
#     ===========================
#     {'amount': 139, 'fr': 'Alma Hindman', 'to': 'Alma Hindman'}
#     'TX OK'
#     '--before--'
#     ('Alma Hindman', 166)
#     ('Alma Hindman', 166)
#     '----------'
#     'Alma Hindman -- 139  --> Alma Hindman'
#     '--after--'
#     ('Alma Hindman', 166)
#     ('Alma Hindman', 166)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#
#     ===========================
#     {'amount': 111, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
#     TX NO FUNDS 100 - 111
#
#     ===========================
#     {'amount': 198, 'fr': 'Carol Clark', 'to': 'Donald Martin'}
#     TX BAD FR: Carol Clark
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#
#     ===========================
#     {'amount': -11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
#     TX NEGATIVE AMOUNT 100 - -11
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#
#     ===========================
#     {'amount': 11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
#     'TX OK'
#     '--before--'
#     ('Eula Zahar', 100)
#     ('Leslie Collingsworth', 0)
#     '----------'
#     'Eula Zahar -- 11  --> Leslie Collingsworth'
#     '--after--'
#     ('Eula Zahar', 89)
#     ('Leslie Collingsworth', 11)
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#     TX NO FUNDS 100 - 111
#     TX BAD FR: Carol Clark
#     TX BAD FR: Eula Zahar
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#     : Eula Zahar
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#     TX NEGATIVE AMOUNT 100 - -11
#
#     ===========================
#     {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
#     TX NEWCOIN OK: coinbase
#     ('Eula Zahar', 0)
#     '100  --> Eula Zahar'
#     ('Eula Zahar', 100)
#     'TX OK'
#     TX NEWCOIN OK: coinbase
#     TX NEWCOIN OK: coinbase

# %% [raw]
# ..............
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Carol Devoe'}
# TX NEWCOIN OK: coinbase
# ('Carol Devoe', 0)
# '100  --> Carol Devoe'
# ('Carol Devoe', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Margaret Williams'}
# TX NEWCOIN OK: coinbase
# ('Margaret Williams', 0)
# '100  --> Margaret Williams'
# ('Margaret Williams', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Sophie Hardin'}
# TX NEWCOIN OK: coinbase
# ('Sophie Hardin', 0)
# '100  --> Sophie Hardin'
# ('Sophie Hardin', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Alma Hindman'}
# TX NEWCOIN OK: coinbase
# ('Alma Hindman', 0)
# '100  --> Alma Hindman'
# ('Alma Hindman', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Karen Langford'}
# TX NEWCOIN OK: coinbase
# ('Karen Langford', 0)
# '100  --> Karen Langford'
# ('Karen Langford', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Leslie Collingsworth'}
# TX NEWCOIN OK: coinbase
# ('Leslie Collingsworth', 0)
# '100  --> Leslie Collingsworth'
# ('Leslie Collingsworth', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Shannon Cano'}
# TX NEWCOIN OK: coinbase
# ('Shannon Cano', 0)
# '100  --> Shannon Cano'
# ('Shannon Cano', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Steven Scott'}
# TX NEWCOIN OK: coinbase
# ('Steven Scott', 0)
# '100  --> Steven Scott'
# ('Steven Scott', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Donald Martin'}
# TX NEWCOIN OK: coinbase
# ('Donald Martin', 0)
# '100  --> Donald Martin'
# ('Donald Martin', 100)
#
# ===========================
# {'amount': 111, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
# TX NO FUNDS 100 - 111
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Shannon Cano'}
# TX NEWCOIN OK: coinbase
# ('Shannon Cano', 100)
# '100  --> Shannon Cano'
# ('Shannon Cano', 200)
#
# ===========================
# {'amount': 83, 'fr': 'Steven Scott', 'to': 'Steven Scott'}
# 'TX OK'
# '--before--'
# ('Steven Scott', 100)
# ('Steven Scott', 100)
# '----------'
# 'Steven Scott -- 83  --> Steven Scott'
# '--after--'
# ('Steven Scott', 100)
# ('Steven Scott', 100)
#
# ===========================
# {'amount': 192, 'fr': 'Alma Hindman', 'to': 'Sophie Hardin'}
# TX NO FUNDS 100 - 192
#
# ===========================
# {'amount': 198, 'fr': 'Carol Clark', 'to': 'Donald Martin'}
# TX BAD FR: Carol Clark
#
# ===========================
# {'amount': 54, 'fr': 'Alice Miller', 'to': 'Karen Langford'}
# TX BAD FR: Alice Miller
#
# ===========================
# {'amount': 104, 'fr': 'Carol Devoe', 'to': 'Steven Scott'}
# TX NO FUNDS 100 - 104
#
# ===========================
# {'amount': 66, 'fr': 'Eula Zahar', 'to': 'Alma Hindman'}
# 'TX OK'
# '--before--'
# ('Eula Zahar', 100)
# ('Alma Hindman', 100)
# '----------'
# 'Eula Zahar -- 66  --> Alma Hindman'
# '--after--'
# ('Eula Zahar', 34)
# ('Alma Hindman', 166)
#
# ===========================
# {'amount': 142, 'fr': 'Sophie Hardin', 'to': 'Steven Scott'}
# TX NO FUNDS 100 - 142
#
# ===========================
# {'amount': 198, 'fr': 'Shannon Cano', 'to': 'Karen Langford'}
# 'TX OK'
# '--before--'
# ('Shannon Cano', 200)
# ('Karen Langford', 100)
# '----------'
# 'Shannon Cano -- 198  --> Karen Langford'
# '--after--'
# ('Shannon Cano', 2)
# ('Karen Langford', 298)
#
# ===========================
# {'amount': 139, 'fr': 'Alma Hindman', 'to': 'Alma Hindman'}
# 'TX OK'
# '--before--'
# ('Alma Hindman', 166)
# ('Alma Hindman', 166)
# '----------'
# 'Alma Hindman -- 139  --> Alma Hindman'
# '--after--'
# ('Alma Hindman', 166)
# ('Alma Hindman', 166)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
#
# ===========================
# {'amount': 111, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
# TX NO FUNDS 100 - 111
#
# ===========================
# {'amount': 198, 'fr': 'Carol Clark', 'to': 'Donald Martin'}
# TX BAD FR: Carol Clark
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
#
# ===========================
# {'amount': -11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
# TX NEGATIVE AMOUNT 100 - -11
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
#
# ===========================
# {'amount': 11, 'fr': 'Eula Zahar', 'to': 'Leslie Collingsworth'}
# 'TX OK'
# '--before--'
# ('Eula Zahar', 100)
# ('Leslie Collingsworth', 0)
# '----------'
# 'Eula Zahar -- 11  --> Leslie Collingsworth'
# '--after--'
# ('Eula Zahar', 89)
# ('Leslie Collingsworth', 11)
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
# TX NO FUNDS 100 - 111
# TX BAD FR: Carol Clark
# TX BAD FR: Eula Zahar
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
# : Eula Zahar
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
# TX NEGATIVE AMOUNT 100 - -11
#
# ===========================
# {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'}
# TX NEWCOIN OK: coinbase
# ('Eula Zahar', 0)
# '100  --> Eula Zahar'
# ('Eula Zahar', 100)
# 'TX OK'
# TX NEWCOIN OK: coinbase
# TX NEWCOIN OK: coinbase
# ----------------------------------------------------------------------
# Ran 14 tests in 0.044s
#
# OK
# <unittest.runner.TextTestResult run=14 errors=0 failures=0>

# %%
dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}
dict['Age'] = 8 # update existing entry
dict['Age'] +=1
print dict['Age']
# Out:
# 9

# %%
for key in dict :
    if key == 'A' :
        print "el7"
checker = False
if checker == False :
    print 'Hi'
# Out:
# Hi

# %%
def test ( tx ):
    if tx['amount'] ==100 :
        print 'Hi'
test( {'amount': 100, 'fr': 'coinbase', 'to': 'Eula Zahar'} )
tx = {'fr':'Coinbase' ,'to':'lola','amount':120}
tx2 ={'fr':'to' ,'to':'lola','amount':120}
print 'TX NEWCOIN OK:' ,tx['fr']
print('Eula Zahar', 0)
print tx['amount']  ,'-->', tx['to']
print ('Eula Zahar', 100)
print (tx['fr'],tx['amount'])
# Out:
# Hi
# TX NEWCOIN OK: Coinbase
# ('Eula Zahar', 0)
# 120 --> lola
# ('Eula Zahar', 100)
# ('Coinbase', 120)

# %%
if 'f'  not in tx  :
    print 'Hi'
print tx['fr']
# Out:
# Hi
# Coinbase

# %%
ff=  {'amount': 192, 'fr': 'Alma Hindman', 'to': 'Sophie Hardin'}
ff[tx['fr']] = 0
print ff
# Out:
# {'Coinbase': 0, 'to': 'Sophie Hardin', 'amount': 192, 'fr': 'Alma Hindman'}

# %%
c={"Alma Hindman": {"privKey": "f697f3ad18b3397dcb45e7e8430d9f12684ed0d5237ad56e", "pubKey": "2c999df45c0a8397831007cd5df6c943578f073169124343df336ef92a41e3259e7646c908c0f09bca9840344c4be8e0"}, "Carol Devoe": {"privKey": "466486c51309b6f62ef9360aaac910f96539aedebc0b649c", "pubKey": "851b73f3a4ee870ccc12d11dbcc58707efc4b2ca6d076ccb303211e99158dd8c0319fe034a079d8a28163ba293f6b1b7"}, "Donald Martin": {"privKey": "e32ae2e45ee31182f5b27dbf5255af35895bb7216a031b03", "pubKey": "4792238e6420d1fbab7de5c37cb9797ca9077fa4649a3397980951cd8d2385d8aa030fb3edc8b67fcff17f71afa5286a"}, "Eula Zahar": {"privKey": "7e045c3b493ba1fe98546e89cf53656d8e75c2bda7dc108a", "pubKey": "4e5ebc838ecf275818e6d5c597a3f426c04265e063c3c4336b62c6be078190c22867bbe6a3be4b23672faac931908cb3"}, "Karen Langford": {"privKey": "dd2700d90e7d9597055030d19c54a5bbca68d95d9b102bb6", "pubKey": "df4dd59b08881d2a69899989f045371c4be1290b5da69049e281a4e99a08100a34a6944b1794825f2274b928bbcfe351"}, "Leslie Collingsworth": {"privKey": "2b6091c8a23b629a6c2497237d32515b4a57a40d8a990021", "pubKey": "cd37e62e31e117ea97dbdbf9dd32953d7ce828b46a72eecd37c8cea569b5baf03f294db30a4b94027e2e736c9926eef1"}, "Margaret Williams": {"privKey": "19c16a17a5d460429a291a2ef62af49431f5afa5fd6dfaa6", "pubKey": "fd823a6878f9b6522fb473cc3a398d00558cfaafd84acc47a4b86f94a6e6cc0734dc67b2473717094b5e110facdcfade"}, "Shannon Cano": {"privKey": "cfbf632cec53302d4dc032e6f5a5b4414a157d8700abb9e6", "pubKey": "7e8bf1485bd3bc5034b1fd3c1cf0e425577d24a089d47bb1752ddb3074c9d7baf5a52f9ca471dade4573a6a8694b17c7"}, "Sophie Hardin": {"privKey": "5b00ec6a8525925fbf41f8f649ec6c67808296e3176770ab", "pubKey": "52e286c4b2905a98e58b2f7e451335bae9d0be8574c2295c1aa059e252917fbf19d5244d4aa40db06babdc4ff66080a4"}, "Steven Scott": {"privKey": "4a95f126a38c6ea0b928b3c46e0cfb6f9093a7fa23242667", "pubKey": "19688ae49aa82d44abf4f772ba71fbbfb75cd7ace94c264d8b6f1a722812a008b4a178c519fd5cfd03e6cfbcaf88fdf6"}, "coinbase": {"privKey": "ac0778da65311fa8f8ed1feaa44687dfc2fa12e79a78eb92", "pubKey": "176d15a06c462548590f0468103a1652b1c120f87fb07dc9397b25ac8718b7b918b218184514e2cbdefdb6028499d2b2"}}
x=c['Alma Hindman']['privKey']

# %%
ff=  {'amount': 192, 'fr': 'Alma Hindman', 'to': 'Sophie Hardin' ,'sig':''}
if not ff['sig'] =='':
    print 'Hi'
